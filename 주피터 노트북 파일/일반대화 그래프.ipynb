# %%
# 파이썬 시각화 패키지 불러오기
import matplotlib.pyplot as plt
import os,re
import numpy as np
# %matplotlib inline


# 사용자 운영체제 확인
import os
os.name
# 운영체제별 한글 폰트 설정
if os.name == 'posix': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif os.name == 'nt': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정

# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %%
#읽어온 txt파일에서 [,],A,:문자 제거 함수
def clean_text(inputString):
    text_rmv = re.sub('[A: \n』‘|\(\)\[\]`\'…》\”\“\’·]', '', inputString)
    make_list = text_rmv.split(',') # ,를 기준으로 리스트 분류
    return make_list

# %%
# 그래프 만들기 위한 x, y좌표 값 생성 함수
def data_graph(undefined_data):
    make_list = clean_text(undefined_data)
    y = make_list
    x = []
    num = 1
    for i in range(len(y)):
        #x_label = num * y
        x.append(num * step)
        num += 1
    return x,y

# %%
file_num = 0 #파일의 개수 확인
#폴더 안에 있는 파일수 함수
files = []
root = "./Real-time Voice Phishing Detection/일반대화 저장 txt 일반대화 그래프/"
file_name = []
file_name = os.listdir(root) #파일 이름만 저장
step = 1 #몇개의 문자로 나눴는지 확인 변수

walk = [root]
while walk:
    folder = walk.pop(0)+"/"
    items = os.listdir(folder) # items = folders + files
    for i in items:
        file_num = file_num +1
        i=folder+i # 파일 경로와 파일이름 맵핑 리스트
        (walk if os.path.isdir(i) else files).append(i)
#print(files)
print(file_name)
# Out:
# ['01.txt', '02.txt', '03.txt', '04.txt', '05.txt']

# %%
x_axis = []
y_axis = []
for i in range(len(files)):
    if os.path.exists(files[i]):
        fr = open(files[i], "r", encoding = 'utf-8')
        lines = fr.read()
        x, y = data_graph(lines)
        fr.close()
        #y_axis.append(y)
        globals()["x{}".format(i)] = list(map(int, x))
        globals()["y{}".format(i)] = list(map(int, y))
        #x_axis.append(intList_x)
        #y_axis.append(intList_y)

# %%
print(x0)
print(y0)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# [0, 0, 0, 0, 0, 0, 0, 0]

# %%
plt.plot(x0, y0, marker="o", alpha=0.5, color='blue', markerfacecolor='None',markeredgecolor='blue',label='non-VP Rec_1')
plt.plot(x1, y1, marker="s", alpha=0.5, color='purple', markerfacecolor='None',markeredgecolor='purple',label='non-VP Rec_2')
plt.plot(x2, y2, marker="v", alpha=0.5, color='magenta', markerfacecolor='None',markeredgecolor='magenta',label='non-VP Rec_3')
plt.plot(x3, y3, marker="d", alpha=0.5, color='green', markerfacecolor='None',markeredgecolor='green', label='non-VP Rec_4')
#plt.plot(x4, y4, marker="x", alpha=0.5, color='red', markerfacecolor='None',markeredgecolor='red', label='non-VP Rec_5')
plt.xlabel('$t_{QA}$', fontsize=13)
plt.ylabel('$P_{vp}$', fontsize=13)
#plt.title('General Conversation' +  '\n Progress')
plt.grid()
plt.legend()
#plt.xticks(np.arange(0, 9)) #x축 눈금 설정
plt.yticks(np.arange(0, 11)) #y축 눈금 설정
#plt.savefig('txt.png')
#plt.close()
plt.show()
plt.close()
